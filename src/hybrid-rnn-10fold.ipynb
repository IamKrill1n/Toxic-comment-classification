# %%
import sys, os, numpy as np, pandas as pd

import re

from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Bidirectional, GlobalMaxPool1D, SimpleRNN, GRU
from keras.layers import SpatialDropout1D, GlobalAveragePooling1D, GlobalMaxPooling1D, concatenate
from keras.models import Model

import gc
from sklearn.preprocessing import StandardScaler
from keras import optimizers

import keras
keras.config.disable_traceback_filtering()
# Out:
# 2024-05-28 03:20:42.661133: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-28 03:20:42.694053: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# quick and dirty way to change the current working directory to root (/toxic-comment-classification)
# you should run this at least once just to be certain
from os import chdir, path, getcwd
if getcwd().endswith("src"):
    chdir(path.pardir)
if path.isfile("checkcwd"):
    print("Success")
else:
    raise Exception("Something went wrong. cwd=" + getcwd())
root_path = os.getcwd()
# Out:
# Success

# %%
from src import constants

# %%
path = 'kaggle/input/'
comp = 'jigsaw-toxic-comment-classification-challenge/'
clean_data_path = 'clean_data/'
EMBEDDING_GLOVE = f'{path}glove_embeddings/glove.6B.300d.txt'
EMBEDDING_FT = f'{path}fasttext_embeddings/wiki-news-300d-1M.vec'
TRAIN_DATA_FILE = f'{path}{comp}train.csv.zip'
TEST_DATA_FILE = f'{path}{comp}test.csv.zip'
CLEAN_TRAIN_DATA_FILE = f'{clean_data_path}data_train_cleaned_light_allcase.txt'
CLEAN_TEST_DATA_FILE = f'{clean_data_path}data_test_cleaned_light_allcase.txt'
SAMPLE_SUBMISSION = f'{path}{comp}sample_submission.csv.zip'

# %% [markdown]
# Embedding parameter

# %%
# values used to get the score
# max_features = 100000 # some big number, bigger than number of unique words(?)
# maxlen = 450 # max number of words in a comment to use
max_features = constants.MAX_FEATURES
maxlen = constants.MAXLEN

# %% [markdown]
# Read data

# %%
train = pd.read_csv(TRAIN_DATA_FILE)
test = pd.read_csv(TEST_DATA_FILE)

def read_from_file(filename):
    with open(filename, 'r') as f:
        return f.read().splitlines()
    
list_sentences_train = read_from_file(CLEAN_TRAIN_DATA_FILE)
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
y = train[list_classes].values
list_sentences_test = read_from_file(CLEAN_TEST_DATA_FILE)

train = train.assign(comment_text=list_sentences_train)
test = test.assign(comment_text=list_sentences_test)

# %%
def add_features(df):
    # work with original text (before preprocessing and cleaning)
    df['comment_text'] = df['comment_text'].apply(lambda x:str(x))
    df['total_length'] = df['comment_text'].apply(len)
    df['capitals'] = df['comment_text'].apply(lambda comment: sum(1 for c in comment if c.isupper()))
    df['caps_vs_length'] = df.apply(lambda row: float(row['capitals'])/float(row['total_length']),
                                axis=1)
    df['num_words'] = df['comment_text'].apply(lambda comment: len(re.findall(r'\S+', comment)))
    df['num_unique_words'] = df['comment_text'].apply(lambda comment: len(set(w for w in comment.split())))
    df['words_vs_unique'] = df['num_unique_words'] / df['num_words']  

    return df

train = add_features(train)
test = add_features(test)

# extract features
features = train[['caps_vs_length', 'words_vs_unique']].fillna(0)
test_features = test[['caps_vs_length', 'words_vs_unique']].fillna(0)

# normalize features
ss = StandardScaler()
ss.fit(np.vstack((features, test_features)))
features = ss.transform(features)
test_features = ss.transform(test_features)
# Out:
# /home/thanh309/miniconda3/envs/thanh309-ml/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/thanh309/miniconda3/envs/thanh309-ml/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %% [markdown]
# Standard keras preprocessing, to turn each comment into a list of word indexes of equal length (with truncation or padding as needed).

# %%
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(list_sentences_train) + list(list_sentences_test))
list_tokenized_train = tokenizer.texts_to_sequences(list_sentences_train)
list_tokenized_test = tokenizer.texts_to_sequences(list_sentences_test)
X_t = pad_sequences(list_tokenized_train, maxlen=maxlen)
X_te = pad_sequences(list_tokenized_test, maxlen=maxlen)

# %%
def get_coefs(word, *arr):
    return word, np.asarray(arr, dtype='float32')
embeddings_index_gl = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_GLOVE))
# embeddings_index_ft = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FT))

# %% [markdown]
# vector: 300 glove + 300 fasttext + 1 allcap

# %%
# word_index = tokenizer.word_index
# nb_words = min(max_features, len(word_index))
# embedding_matrix = np.zeros((nb_words, 601))


# # something: filler word for empty comment

# # word2vec of 'something'
# something_gl = embeddings_index_gl.get("something")
# something_ft = embeddings_index_ft.get("something")

# something = np.zeros((601,))
# something[:300, ] = something_gl
# something[300:600, ] = something_ft
# something[600, ] = 0

# %%
# def all_caps(word: str) -> bool:
#     return len(word) > 1 and word.isupper()

# def embed_word(embedding_matrix, i, word):
#     embedding_vector_ft = embeddings_index_ft.get(word)
#     if embedding_vector_ft is not None:
#         # embed word if is exists in fasttext dict
#         if all_caps(word):
#             last_value = np.array([1])
#         else:
#             last_value = np.array([0])
#         embedding_vector_gl = embeddings_index_gl.get(word)
#         if embedding_vector_gl is not None:
#             embedding_matrix[i, :300] = embedding_vector_gl
#         embedding_matrix[i, 300:600] = embedding_vector_ft
#         embedding_matrix[i, 600] = last_value
#     else:
#         # embed word with filler word
#         embedding_matrix[i] = something


# for word, i in word_index.items():
#     if i >= max_features:
#         continue
#     embed_word(embedding_matrix, i, word)

# %% [markdown]
# Ver 2: 300 glove + 1 allcap

# %%
word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.zeros((nb_words, 301))


# something: filler word for empty comment

# word2vec of 'something'
something_gl = embeddings_index_gl.get("something")
# something_ft = embeddings_index_ft.get("something")

something = np.zeros((301,))
something[:300, ] = something_gl
# something[300:600, ] = something_ft
something[300, ] = 0

# %%
def all_caps(word: str) -> bool:
    return len(word) > 1 and word.isupper()

def embed_word(embedding_matrix, i, word):
    if all_caps(word):
        last_value = np.array([1])
    else:
        last_value = np.array([0])
    embedding_vector_gl = embeddings_index_gl.get(word)
    if embedding_vector_gl is not None:
        embedding_matrix[i, :300] = embedding_vector_gl
        embedding_matrix[i, 300] = last_value
    else:
        # embed word with filler word
        embedding_matrix[i] = something


for word, i in word_index.items():
    if i >= max_features:
        continue
    embed_word(embedding_matrix, i, word)
# Out:
# /tmp/ipykernel_2797/771730870.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   embedding_matrix[i, 300] = last_value

# %%
# embeddings_index_ft = None
embeddings_index_gl = None
gc.collect()
# Out:
# 0

# %%
def get_model(features, clipvalue=1., num_filters=40, dropout=0.5, embed_size=301):

    inp = Input(shape=(maxlen,))
    # print(inp.shape)
    
    # Layer 1: concatenated fasttext and glove twitter embeddings
    x = Embedding(max_features, embed_size, weights=[embedding_matrix], trainable=False)(inp)
    # print(x.shape)
    
    # Layer 2: SpatialDropout1D(0.5)
    x = SpatialDropout1D(dropout)(x)
    
    # Layer 3: Bidirectional CuDNNLSTM
    x = Bidirectional(LSTM(num_filters, return_sequences=True))(x)


    # Layer 4: Bidirectional CuDNNGRU
    x = Bidirectional(GRU(num_filters, return_sequences=True))(x)
    
    # Layer 5: A concatenation of maximum pool, average pool and 
    # two features: "Unique words rate" and "Rate of all-caps words"
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    features_input = Input(shape=(features.shape[1],))
    
    x = concatenate([avg_pool, max_pool, features_input])
    
    # Layer 6: output dense layer.
    outp = Dense(6, activation="sigmoid")(x)

    model = Model(inputs=[inp,features_input], outputs=outp)
    adam = optimizers.Adam(clipvalue=clipvalue)
    model.compile(loss='binary_crossentropy',
                  optimizer=adam,
                  metrics=['accuracy'])
    return model

# %%
from keras.callbacks import Callback
from sklearn.metrics import roc_auc_score

checkpoint_path = 'model_checkpoint/'

class RocAucEvaluation(Callback):
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()
        self.interval = interval
        self.X_val, self.y_val = validation_data
        self.max_score = 0
        self.not_better_count = 0

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=1)
            score = roc_auc_score(self.y_val, y_pred)
            print("\n ROC-AUC - epoch: %d - score: %.6f \n" % (epoch+1, score))
            if (score > self.max_score):
                print("*** New High Score (previous: %.6f) \n" % self.max_score)
                self.model.save_weights(checkpoint_path + "best.weights.h5")
                self.max_score=score
                self.not_better_count = 0
            else:
                self.not_better_count += 1
                if self.not_better_count > 3:
                    print("Epoch %05d: early stopping, high score = %.6f" % (epoch,self.max_score))
                    self.model.stop_training = True

# %%
from keras import backend as K
from sklearn.model_selection import KFold
import keras
keras.config.disable_traceback_filtering()

model = get_model(features)

# values used to get the score
# batch_size = 96
# epochs = 10
# num_folds = 10

batch_size = constants.BATCH_SIZE
epochs = constants.EPOCHS
num_folds = constants.NUM_FOLDS

gc.collect()
K.clear_session()

# Uncomment for out-of-fold predictions
scores = []
oof_predict = np.zeros((train.shape[0], 6))

predict = np.zeros((test.shape[0], 6))
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

for train_index, test_index in kf.split(X_t):
    
    kfold_y_train, kfold_y_test = y[train_index], y[test_index]
    kfold_X_train = X_t[train_index]
    kfold_X_features = features[train_index]
    kfold_X_valid = X_t[test_index]
    kfold_X_valid_features = features[test_index] 
    
    gc.collect()
    K.clear_session()
    
    model = get_model(features)
    
    
    ra_val = RocAucEvaluation(validation_data=([kfold_X_valid, kfold_X_valid_features], kfold_y_test), interval = 1)
    
    model.fit([kfold_X_train,kfold_X_features], kfold_y_train, batch_size=batch_size, epochs=epochs, verbose=1,
             callbacks = [ra_val])
    
    gc.collect()
    
    #model.load_weights(bst_model_path)
    model.load_weights(checkpoint_path + "best.weights.h5")
    
    predict += model.predict([X_te, test_features], batch_size=batch_size, verbose=1) / num_folds
    
    gc.collect()
    # uncomment for out of fold predictions
    oof_predict[test_index] = model.predict([kfold_X_valid, kfold_X_valid_features], batch_size=batch_size, verbose=1)
    cv_score = roc_auc_score(kfold_y_test, oof_predict[test_index])
    
    scores.append(cv_score)
    print('score: ', cv_score)


print("Done")
#
print('Total CV score is {}'.format(np.mean(scores)))

sample_submission = pd.read_csv(SAMPLE_SUBMISSION)
sample_submission[list_classes] = predict
sample_submission.to_csv(root_path + '/kaggle/working/' + '4_sub.csv', index=False)

# uncomment for out of fold predictions
oof = pd.DataFrame.from_dict({'id': train['id']})
for c in list_classes:
   oof[c] = np.zeros(len(train))
   
oof[list_classes] = oof_predict
oof.to_csv(root_path + '/kaggle/working/' + '4_oof.csv', index=False)
# Out:
# 2024-05-28 03:21:12.459745: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.482275: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.482310: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.485856: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.485901: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.485915: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.615774: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.615813: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.615819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-28 03:21:12.615839: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-28 03:21:12.615859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/10
# 2024-05-28 03:21:16.516021: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.974946
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 145s 95ms/step - accuracy: 0.9114 - loss: 0.1135
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.981481
#
# *** New High Score (previous: 0.974946)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9930 - loss: 0.0526
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.984845
#
# *** New High Score (previous: 0.981481)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9892 - loss: 0.0481
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.986417
#
# *** New High Score (previous: 0.984845)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9891 - loss: 0.0458
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.987354
#
# *** New High Score (previous: 0.986417)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9869 - loss: 0.0440
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.987700
#
# *** New High Score (previous: 0.987354)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9894 - loss: 0.0420
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.987321
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9865 - loss: 0.0421
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.987527
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9886 - loss: 0.0412
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.988075
#
# *** New High Score (previous: 0.987700)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 203s 95ms/step - accuracy: 0.9830 - loss: 0.0413
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.987862
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9862 - loss: 0.0398
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step
# score:  0.9880747587805407
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.973768
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9453 - loss: 0.1096
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.981393
#
# *** New High Score (previous: 0.973768)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9929 - loss: 0.0509
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.985144
#
# *** New High Score (previous: 0.981393)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9900 - loss: 0.0469
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.986524
#
# *** New High Score (previous: 0.985144)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9875 - loss: 0.0451
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.987461
#
# *** New High Score (previous: 0.986524)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9870 - loss: 0.0432
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.988118
#
# *** New High Score (previous: 0.987461)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9859 - loss: 0.0421
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.988185
#
# *** New High Score (previous: 0.988118)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9860 - loss: 0.0416
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.988426
#
# *** New High Score (previous: 0.988185)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9847 - loss: 0.0408
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.988579
#
# *** New High Score (previous: 0.988426)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9859 - loss: 0.0404
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.988915
#
# *** New High Score (previous: 0.988579)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9861 - loss: 0.0395
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 32ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
# score:  0.9889148568851591
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.975746
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.8719 - loss: 0.1083
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.982192
#
# *** New High Score (previous: 0.975746)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9906 - loss: 0.0523
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.985947
#
# *** New High Score (previous: 0.982192)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9911 - loss: 0.0475
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.987299
#
# *** New High Score (previous: 0.985947)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9876 - loss: 0.0457
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.987657
#
# *** New High Score (previous: 0.987299)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9843 - loss: 0.0445
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.988518
#
# *** New High Score (previous: 0.987657)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9863 - loss: 0.0430
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.989082
#
# *** New High Score (previous: 0.988518)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9835 - loss: 0.0417
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.989495
#
# *** New High Score (previous: 0.989082)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9846 - loss: 0.0410
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.989278
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9840 - loss: 0.0408
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.989093
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9821 - loss: 0.0399
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
# score:  0.9894948629234211
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.978231
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.8969 - loss: 0.1152
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.984166
#
# *** New High Score (previous: 0.978231)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9901 - loss: 0.0511
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.985841
#
# *** New High Score (previous: 0.984166)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9910 - loss: 0.0468
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.986481
#
# *** New High Score (previous: 0.985841)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9850 - loss: 0.0443
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.987026
#
# *** New High Score (previous: 0.986481)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9800 - loss: 0.0437
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.987129
#
# *** New High Score (previous: 0.987026)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9719 - loss: 0.0417
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.987064
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9826 - loss: 0.0413
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.987490
#
# *** New High Score (previous: 0.987129)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9781 - loss: 0.0409
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.987481
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9748 - loss: 0.0403
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.987445
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9786 - loss: 0.0398
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
# score:  0.9874895490022633
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.971277
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9478 - loss: 0.1137
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.980386
#
# *** New High Score (previous: 0.971277)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9929 - loss: 0.0522
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.983040
#
# *** New High Score (previous: 0.980386)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9915 - loss: 0.0482
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.984920
#
# *** New High Score (previous: 0.983040)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9913 - loss: 0.0454
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.985369
#
# *** New High Score (previous: 0.984920)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9898 - loss: 0.0433
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.985742
#
# *** New High Score (previous: 0.985369)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9877 - loss: 0.0426
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.986276
#
# *** New High Score (previous: 0.985742)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9874 - loss: 0.0421
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.986418
#
# *** New High Score (previous: 0.986276)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9851 - loss: 0.0410
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.986385
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9864 - loss: 0.0407
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.986956
#
# *** New High Score (previous: 0.986418)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9859 - loss: 0.0395
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step
# score:  0.9869563857205018
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.975292
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9077 - loss: 0.1108
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.981234
#
# *** New High Score (previous: 0.975292)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9923 - loss: 0.0506
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.984099
#
# *** New High Score (previous: 0.981234)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9895 - loss: 0.0478
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.985370
#
# *** New High Score (previous: 0.984099)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9901 - loss: 0.0452
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.986277
#
# *** New High Score (previous: 0.985370)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9885 - loss: 0.0441
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.986483
#
# *** New High Score (previous: 0.986277)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9878 - loss: 0.0419
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.986919
#
# *** New High Score (previous: 0.986483)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9871 - loss: 0.0417
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.986620
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9851 - loss: 0.0406
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.986954
#
# *** New High Score (previous: 0.986919)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 141s 95ms/step - accuracy: 0.9864 - loss: 0.0402
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.987023
#
# *** New High Score (previous: 0.986954)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9832 - loss: 0.0400
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 32ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
# score:  0.9870231692803119
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.974467
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9069 - loss: 0.1129
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.981472
#
# *** New High Score (previous: 0.974467)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9910 - loss: 0.0514
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.984316
#
# *** New High Score (previous: 0.981472)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9902 - loss: 0.0470
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.985576
#
# *** New High Score (previous: 0.984316)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9878 - loss: 0.0454
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.986337
#
# *** New High Score (previous: 0.985576)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9870 - loss: 0.0433
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.986255
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9869 - loss: 0.0421
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.986793
#
# *** New High Score (previous: 0.986337)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9870 - loss: 0.0406
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.986853
#
# *** New High Score (previous: 0.986793)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9829 - loss: 0.0406
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.986927
#
# *** New High Score (previous: 0.986853)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9869 - loss: 0.0396
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.987092
#
# *** New High Score (previous: 0.986927)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9811 - loss: 0.0392
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
# score:  0.987092269940241
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.973711
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9585 - loss: 0.1100
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.979662
#
# *** New High Score (previous: 0.973711)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9925 - loss: 0.0516
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.982914
#
# *** New High Score (previous: 0.979662)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9908 - loss: 0.0486
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.983819
#
# *** New High Score (previous: 0.982914)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9892 - loss: 0.0450
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.985288
#
# *** New High Score (previous: 0.983819)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9893 - loss: 0.0442
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.985398
#
# *** New High Score (previous: 0.985288)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9890 - loss: 0.0429
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.985973
#
# *** New High Score (previous: 0.985398)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9880 - loss: 0.0417
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.986250
#
# *** New High Score (previous: 0.985973)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9857 - loss: 0.0417
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.986045
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9849 - loss: 0.0398
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.986082
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9832 - loss: 0.0395
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
# score:  0.9862504568974012
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.973435
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 144s 95ms/step - accuracy: 0.9582 - loss: 0.1072
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.980660
#
# *** New High Score (previous: 0.973435)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9910 - loss: 0.0517
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.984717
#
# *** New High Score (previous: 0.980660)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9889 - loss: 0.0483
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.986297
#
# *** New High Score (previous: 0.984717)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9886 - loss: 0.0464
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.986979
#
# *** New High Score (previous: 0.986297)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9878 - loss: 0.0445
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.987633
#
# *** New High Score (previous: 0.986979)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9858 - loss: 0.0429
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.987720
#
# *** New High Score (previous: 0.987633)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9865 - loss: 0.0419
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.988026
#
# *** New High Score (previous: 0.987720)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9879 - loss: 0.0410
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.987955
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9881 - loss: 0.0402
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.988022
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9849 - loss: 0.0405
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 50s 32ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
# score:  0.9880260552841468
# Epoch 1/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 1 - score: 0.973682
#
# *** New High Score (previous: 0.000000)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 145s 96ms/step - accuracy: 0.9044 - loss: 0.1118
# Epoch 2/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 2 - score: 0.978978
#
# *** New High Score (previous: 0.973682)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9928 - loss: 0.0515
# Epoch 3/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 3 - score: 0.982638
#
# *** New High Score (previous: 0.978978)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9901 - loss: 0.0478
# Epoch 4/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 4 - score: 0.983540
#
# *** New High Score (previous: 0.982638)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9871 - loss: 0.0454
# Epoch 5/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 5 - score: 0.984033
#
# *** New High Score (previous: 0.983540)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9868 - loss: 0.0434
# Epoch 6/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 6 - score: 0.984714
#
# *** New High Score (previous: 0.984033)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9838 - loss: 0.0420
# Epoch 7/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 7 - score: 0.985060
#
# *** New High Score (previous: 0.984714)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9881 - loss: 0.0415
# Epoch 8/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 8 - score: 0.985324
#
# *** New High Score (previous: 0.985060)
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9840 - loss: 0.0406
# Epoch 9/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
#  ROC-AUC - epoch: 9 - score: 0.985065
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9863 - loss: 0.0405
# Epoch 10/10
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step
#
#  ROC-AUC - epoch: 10 - score: 0.985055
#
# 1496/1496 ━━━━━━━━━━━━━━━━━━━━ 143s 95ms/step - accuracy: 0.9815 - loss: 0.0397
# 1596/1596 ━━━━━━━━━━━━━━━━━━━━ 51s 32ms/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step
# score:  0.9853235611398375
# Done
# Total CV score is 0.9874645925853824
